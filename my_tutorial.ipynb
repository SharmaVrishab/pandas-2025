# %%
import pandas as pd

# %%
coffee = pd.read_csv("./warmup-data/coffee.csv")

# %%
print(coffee.head())
# Out:
#          Day Coffee Type  Units Sold
# 0     Monday    Espresso          25
# 1     Monday       Latte          15
# 2    Tuesday    Espresso          30
# 3    Tuesday       Latte          20
# 4  Wednesday    Espresso          35

# %%
olympics = pd.read_excel("./data/olympics-data.xlsx",sheet_name="results")

# %%
print(olympics.head())
# Out:
#      year    type discipline                     event                     as  \
# 0  1912.0  Summer     Tennis    Singles, Men (Olympic)  Jean-François Blanchy
# 1  1912.0  Summer     Tennis    Doubles, Men (Olympic)  Jean-François Blanchy
# 2  1920.0  Summer     Tennis    Singles, Men (Olympic)  Jean-François Blanchy
# 3  1920.0  Summer     Tennis  Doubles, Mixed (Olympic)  Jean-François Blanchy
# 4  1920.0  Summer     Tennis    Doubles, Men (Olympic)  Jean-François Blanchy
#
#    athlete_id  noc             team  place   tied medal
# 0           1  FRA              NaN   17.0   True   NaN
# 1           1  FRA   Jean Montariol    NaN  False   NaN
# 2           1  FRA              NaN   32.0   True   NaN
# 3           1  FRA  Jeanne Vaussard    8.0   True   NaN
# 4           1  FRA  Jacques Brugnon    4.0  False   NaN

# %%
coffee = pd.read_csv("./warmup-data/coffee.csv")

# %%
coffee.head(10)
# Out:
#          Day Coffee Type  Units Sold
# 0     Monday    Espresso          25
# 1     Monday       Latte          15
# 2    Tuesday    Espresso          30
# 3    Tuesday       Latte          20
# 4  Wednesday    Espresso          35
# 5  Wednesday       Latte          25
# 6   Thursday    Espresso          40
# 7   Thursday       Latte          30
# 8     Friday    Espresso          45
# 9     Friday       Latte          35

# %%
coffee.tail()
# Out:
#          Day Coffee Type  Units Sold
# 9     Friday       Latte          35
# 10  Saturday    Espresso          45
# 11  Saturday       Latte          35
# 12    Sunday    Espresso          45
# 13    Sunday       Latte          35

# %%
coffee.sample(10)
# to get random data
# Out:
#           Day Coffee Type  Units Sold
# 3     Tuesday       Latte          20
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 12     Sunday    Espresso          45
# 2     Tuesday    Espresso          30
# 1      Monday       Latte          15
# 9      Friday       Latte          35
# 4   Wednesday    Espresso          35
# 5   Wednesday       Latte          25
# 11   Saturday       Latte          35

# %%
# to get specific value loc and iloc
coffee.loc[1:5,["Day","Units Sold"]]
# Out:
#          Day  Units Sold
# 1     Monday          15
# 2    Tuesday          30
# 3    Tuesday          20
# 4  Wednesday          35
# 5  Wednesday          25

# %%
coffee.iloc[1:5,0:3]
# Out:
#          Day Coffee Type  Units Sold
# 1     Monday       Latte          15
# 2    Tuesday    Espresso          30
# 3    Tuesday       Latte          20
# 4  Wednesday    Espresso          35

# %%
coffee.index = coffee.Day

# %%
coffee.loc["Monday":"Tuesday"]
# Out:
#              Day Coffee Type  Units Sold
# Day
# Monday    Monday    Espresso          25
# Monday    Monday       Latte          15
# Tuesday  Tuesday    Espresso          30
# Tuesday  Tuesday       Latte          20

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso          25
# 1      Monday       Latte          15
# 2     Tuesday    Espresso          30
# 3     Tuesday       Latte          20
# 4   Wednesday    Espresso          35
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35

# %%
coffee.loc[1,"Units Sold"] = 10

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso          25
# 1      Monday       Latte          10
# 2     Tuesday    Espresso          30
# 3     Tuesday       Latte          20
# 4   Wednesday    Espresso          35
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35

# %%
#  this is more easy way for accessing the value 
coffee.at[0,"Units Sold"]
# Out:
# np.int64(25)

# %%
#  example for accessing the data and it is faster than iloc but can only get single value 
data = {'A': [1, 2, 3], 'B': [4, 5, 6]}
df = pd.DataFrame(data, index=['x', 'y', 'z'])

# Access the value at row 'y' and column 'B'
value = df.at['y', 'B']
print(value)  # Output: 5
# Out:
# 5

# %%
coffee.Day
# Out:
# 0        Monday
# 1        Monday
# 2       Tuesday
# 3       Tuesday
# 4     Wednesday
# 5     Wednesday
# 6      Thursday
# 7      Thursday
# 8        Friday
# 9        Friday
# 10     Saturday
# 11     Saturday
# 12       Sunday
# 13       Sunday
# Name: Day, dtype: object

# %%
#  we can also sort values 
coffee.sort_values("Units Sold")
#  this is in ascending or increasing order
# Out:
#           Day Coffee Type  Units Sold
# 1      Monday       Latte          10
# 3     Tuesday       Latte          20
# 0      Monday    Espresso          25
# 5   Wednesday       Latte          25
# 2     Tuesday    Espresso          30
# 7    Thursday       Latte          30
# 4   Wednesday    Espresso          35
# 9      Friday       Latte          35
# 11   Saturday       Latte          35
# 13     Sunday       Latte          35
# 6    Thursday    Espresso          40
# 8      Friday    Espresso          45
# 10   Saturday    Espresso          45
# 12     Sunday    Espresso          45

# %%
#  we can also sort values for descending order
coffee.sort_values("Units Sold",ascending=False)
#  this is in descending  or decreasing  order
# Out:
#           Day Coffee Type  Units Sold
# 8      Friday    Espresso          45
# 10   Saturday    Espresso          45
# 12     Sunday    Espresso          45
# 6    Thursday    Espresso          40
# 4   Wednesday    Espresso          35
# 9      Friday       Latte          35
# 11   Saturday       Latte          35
# 13     Sunday       Latte          35
# 2     Tuesday    Espresso          30
# 7    Thursday       Latte          30
# 0      Monday    Espresso          25
# 5   Wednesday       Latte          25
# 3     Tuesday       Latte          20
# 1      Monday       Latte          10

# %%
# we can also iterate over our data 
for index,row in coffee.iterrows():
    print(index)
    print(row)
    print("\n \n \n \n")
# Out:
# 0
# Day              Monday
# Coffee Type    Espresso
# Units Sold           25
# Name: 0, dtype: object
#
#
#
#
#
# 1
# Day            Monday
# Coffee Type     Latte
# Units Sold         10
# Name: 1, dtype: object
#
#
#
#
#
# 2
# Day             Tuesday
# Coffee Type    Espresso
# Units Sold           30
# Name: 2, dtype: object
#
#
#
#
#
# 3
# Day            Tuesday
# Coffee Type      Latte
# Units Sold          20
# Name: 3, dtype: object
#
#
#
#
#
# 4
# Day            Wednesday
# Coffee Type     Espresso
# Units Sold            35
# Name: 4, dtype: object
#
#
#
#
#
# 5
# Day            Wednesday
# Coffee Type        Latte
# Units Sold            25
# Name: 5, dtype: object
#
#
#
#
#
# 6
# Day            Thursday
# Coffee Type    Espresso
# Units Sold           40
# Name: 6, dtype: object
#
#
#
#
#
# 7
# Day            Thursday
# Coffee Type       Latte
# Units Sold           30
# Name: 7, dtype: object
#
#
#
#
#
# 8
# Day              Friday
# Coffee Type    Espresso
# ...

# %% [markdown]
# FILTERING THE DATA

# %%
bios = pd.read_csv("./data/bios.csv")

# %%
bios.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg   died_date
# 0               Gironde          FRA  France        NaN        NaN  1960-10-02
# 1              Yvelines          FRA  France      183.0       76.0         NaN
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0  1994-07-17
# 3                 Paris          FRA  France      168.0       64.0  1978-03-20
# 4               England          GBR  France        NaN        NaN  1930-07-25

# %%
bios.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145500 entries, 0 to 145499
# Data columns (total 10 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   athlete_id    145500 non-null  int64
#  1   name          145500 non-null  object
#  2   born_date     143693 non-null  object
#  3   born_city     110908 non-null  object
#  4   born_region   110908 non-null  object
#  5   born_country  110908 non-null  object
#  6   NOC           145499 non-null  object
#  7   height_cm     106651 non-null  float64
#  8   weight_kg     102070 non-null  float64
#  9   died_date     33940 non-null   object
# dtypes: float64(2), int64(1), object(7)
# memory usage: 11.1+ MB

# %%
bios.index = bios.name
bios.loc[(bios['height_cm']> 215) & (bios['born_country'] ==  "USA"), ["height_cm","born_country"]].sort_values("height_cm")
# Out:
#                   height_cm born_country
# name
# Shaquille O'Neal      216.0          USA
# David Robinson        216.0          USA
# Tyson Chandler        216.0          USA
# Tommy Burleson        223.0          USA

# %%
bios.loc[bios['name'].str.contains("keith|wallace", case=False)]
# Out:
#         athlete_id                     name   born_date    born_city  \
# 1897          1907             Keith Hanlon  1966-09-01          NaN
# 2216          2226           Wallace Bryant  1863-12-19      Melrose
# 3242          3254            B. J. Wallace  1971-05-18       Mobile
# 3505          3517            Keith Wallace  1961-03-29      Preston
# 6228          6255            Keith Hartley  1940-10-15    Vancouver
# ...            ...                      ...         ...          ...
# 132575      135452  Shawn Dingilius-Wallace  1994-07-26          NaN
# 134189      137224            Lloyd Wallace  1995-02-13  Southampton
# 137246      140596       Bernadette Wallace  1989-08-08          NaN
# 138135      141527            Jamie Wallace  1999-09-14    Vancouver
# 139683      143160             Zach Wallace  1999-09-29      Redhill
#
#              born_region born_country            NOC  height_cm  weight_kg  \
# ...

# %% [markdown]
# <!-- we can also filer the data based on predefined list using .isin() method -->

# %%
bios[bios['born_country'].isin(["USA","FRA","GBR"])]
# Out:
#         athlete_id                   name   born_date      born_city  \
# 0                1  Jean-François Blanchy  1886-12-12       Bordeaux
# 1                2         Arnaud Boetsch  1969-04-01         Meulan
# 2                3           Jean Borotra  1898-08-13       Biarritz
# 3                4        Jacques Brugnon  1895-05-11    Paris VIIIe
# 4                5           Albert Canet  1878-04-17     Wandsworth
# ...            ...                    ...         ...            ...
# 145454      149180          Anna Hoffmann  2000-03-28        Madison
# 145457      149183         Alix Wilkinson  2000-08-02  Mammoth Lakes
# 145467      149194            Elisa Nakab  1998-05-08       Briançon
# 145468      149195      Justin Abdelkader  1987-02-25       Muskegon
# 145498      149225         André Foussard  1899-05-19          Niort
#
#                  born_region born_country            NOC  height_cm  \
# 0                    Gironde          FRA         France        NaN
# ...

# %%
# STRING BASED FILERITNG DATA METHOD 
#  slighly slower than loc
bios.query("born_country == 'USA' and height_cm > 160")
# Out:
#         athlete_id                  name   born_date          born_city  \
# 54              55         Monique Javer  1967-07-22         Burlingame
# 960            964      Xóchitl Escobedo  1968-09-17        West Covina
# 1345          1352            Laura Berg  1975-01-06   Santa Fe Springs
# 1346          1353          Gillian Boxx  1973-09-01            Fontana
# 1356          1363  Sheila Cornell-Douty  1962-02-26             Encino
# ...            ...                   ...         ...                ...
# 144388      148078          Zhang Xifang  2000-12-20  Commerce Township
# 144398      148088               Jian An  1990-09-15             Irvine
# 144400      148090      Shimisi Jieruimi  1989-04-13           Dearborn
# 144977      148686      Atle Lie McGrath  2000-04-21         Burlington
# 145468      149195     Justin Abdelkader  1987-02-25           Muskegon
#
#        born_region born_country                         NOC  height_cm  \
# ...

# %%
coffee.head()
# Out:
#          Day Coffee Type  Units Sold
# 0     Monday    Espresso          25
# 1     Monday       Latte          15
# 2    Tuesday    Espresso          30
# 3    Tuesday       Latte          20
# 4  Wednesday    Espresso          35

# %%
coffee['price'] = 4.99

# %%
import numpy as np
#  here i am just making a copy of coffee so that the actual data does not change 
coffee_new = coffee.copy()
coffee_new['new_price'] = np.where(coffee['Coffee Type'] == 'Espresso',3.99,5.99)

# %%
coffee_new.head()
# Out:
#          Day Coffee Type  Units Sold  new_price
# 0     Monday    Espresso          25       3.99
# 1     Monday       Latte          15       5.99
# 2    Tuesday    Espresso          30       3.99
# 3    Tuesday       Latte          20       5.99
# 4  Wednesday    Espresso          35       3.99

# %%
#  but there is extra column we have to drop column 
coffee.drop(columns=['price'],inplace=True)

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso          25
# 1      Monday       Latte          15
# 2     Tuesday    Espresso          30
# 3     Tuesday       Latte          20
# 4   Wednesday    Espresso          35
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35

# %%
coffee_new['revenue'] = coffee_new['Units Sold'] * coffee_new['new_price']

# %%
coffee_new.head()
# Out:
#          Day Coffee Type  Units Sold  new_price  revenue
# 0     Monday    Espresso          25       3.99    99.75
# 1     Monday       Latte          15       5.99    89.85
# 2    Tuesday    Espresso          30       3.99   119.70
# 3    Tuesday       Latte          20       5.99   119.80
# 4  Wednesday    Espresso          35       3.99   139.65

# %%
coffee_new.rename(columns={'new_price':'price'},inplace=True)

# %%
coffee_new.head()
# Out:
#          Day Coffee Type  Units Sold  price  revenue
# 0     Monday    Espresso          25   3.99    99.75
# 1     Monday       Latte          15   5.99    89.85
# 2    Tuesday    Espresso          30   3.99   119.70
# 3    Tuesday       Latte          20   5.99   119.80
# 4  Wednesday    Espresso          35   3.99   139.65

# %%
bios.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg   died_date
# 0               Gironde          FRA  France        NaN        NaN  1960-10-02
# 1              Yvelines          FRA  France      183.0       76.0         NaN
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0  1994-07-17
# 3                 Paris          FRA  France      168.0       64.0  1978-03-20
# 4               England          GBR  France        NaN        NaN  1930-07-25

# %%
bios_new = bios.copy()

# %%
bios_new['first_name'] = bios_new['name'].str.split(' ').str[0]

# %%
bios_new.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg  \
# 0               Gironde          FRA  France        NaN        NaN
# 1              Yvelines          FRA  France      183.0       76.0
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0
# 3                 Paris          FRA  France      168.0       64.0
# 4               England          GBR  France        NaN        NaN
#
#     died_date     first_name
# 0  1960-10-02  Jean-François
# 1         NaN         Arnaud
# 2  1994-07-17           Jean
# 3  1978-03-20        Jacques
# 4  1930-07-25         Albert

# %%
bios_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145500 entries, 0 to 145499
# Data columns (total 11 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   athlete_id    145500 non-null  int64
#  1   name          145500 non-null  object
#  2   born_date     143693 non-null  object
#  3   born_city     110908 non-null  object
#  4   born_region   110908 non-null  object
#  5   born_country  110908 non-null  object
#  6   NOC           145499 non-null  object
#  7   height_cm     106651 non-null  float64
#  8   weight_kg     102070 non-null  float64
#  9   died_date     33940 non-null   object
#  10  first_name    145500 non-null  object
# dtypes: float64(2), int64(1), object(8)
# memory usage: 12.2+ MB

# %% [markdown]
# using pandas to convert it to date time object

# %%
bios_new["born_datetime"] = pd.to_datetime(bios_new['born_date'])

# %%
bios_new.head()
# Out:
#    athlete_id                   name  born_date    born_city  \
# 0           1  Jean-François Blanchy 1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch 1969-04-01       Meulan
# 2           3           Jean Borotra 1898-08-13     Biarritz
# 3           4        Jacques Brugnon 1895-05-11  Paris VIIIe
# 4           5           Albert Canet 1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg  \
# 0               Gironde          FRA  France        NaN        NaN
# 1              Yvelines          FRA  France      183.0       76.0
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0
# 3                 Paris          FRA  France      168.0       64.0
# 4               England          GBR  France        NaN        NaN
#
#     died_date     first_name born_datetime
# 0  1960-10-02  Jean-François    1886-12-12
# 1         NaN         Arnaud    1969-04-01
# 2  1994-07-17           Jean    1898-08-13
# ...

# %%
bios_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145500 entries, 0 to 145499
# Data columns (total 12 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   athlete_id     145500 non-null  int64
#  1   name           145500 non-null  object
#  2   born_date      143693 non-null  datetime64[ns]
#  3   born_city      110908 non-null  object
#  4   born_region    110908 non-null  object
#  5   born_country   110908 non-null  object
#  6   NOC            145499 non-null  object
#  7   height_cm      106651 non-null  float64
#  8   weight_kg      102070 non-null  float64
#  9   died_date      33940 non-null   object
#  10  first_name     145500 non-null  object
#  11  born_datetime  143693 non-null  datetime64[ns]
# dtypes: datetime64[ns](2), float64(2), int64(1), object(7)
# memory usage: 13.3+ MB

# %% [markdown]
# we can use that to extract information regarding to the date object

# %%
bios_new["birth_year"] = bios_new['born_datetime'].dt.year

# %%
bios_new.head()
# Out:
#    athlete_id                   name  born_date    born_city  \
# 0           1  Jean-François Blanchy 1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch 1969-04-01       Meulan
# 2           3           Jean Borotra 1898-08-13     Biarritz
# 3           4        Jacques Brugnon 1895-05-11  Paris VIIIe
# 4           5           Albert Canet 1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg  \
# 0               Gironde          FRA  France        NaN        NaN
# 1              Yvelines          FRA  France      183.0       76.0
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0
# 3                 Paris          FRA  France      168.0       64.0
# 4               England          GBR  France        NaN        NaN
#
#     died_date     first_name born_datetime  birth_year
# 0  1960-10-02  Jean-François    1886-12-12      1886.0
# 1         NaN         Arnaud    1969-04-01      1969.0
# ...

# %% [markdown]
# Saving to csv file

# %%
bios_new.to_csv('./data/bios_new.csv',index=False)

# %% [markdown]
# ADDMING AND REMOVING COLUMNS

# %%
# APPPLYING CUSTOM FUNCTION 
bios['height_category'] = bios['height_cm'].apply(lambda x: 'SHORT' if x<165 else ('Average' if x < 185 else 'Tall') )

# %%
bios.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg  \
# 0               Gironde          FRA  France        NaN        NaN
# 1              Yvelines          FRA  France      183.0       76.0
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0
# 3                 Paris          FRA  France      168.0       64.0
# 4               England          GBR  France        NaN        NaN
#
#     died_date height_category
# 0  1960-10-02            Tall
# 1         NaN         Average
# 2  1994-07-17         Average
# 3  1978-03-20         Average
# 4  1930-07-25            Tall

# %%
def categorize_athlete(row):
    if row['height_cm'] < 175 and row['weight_kg'] < 70:
        return 'Lightweight'
    elif row['height_cm'] < 185 or row['weight_kg'] <= 80:
        return 'Middleweight'
    
    else:
        return 'Heavyweight'
# 1 is row and 0 is columns 
bios['Category'] = bios.apply(categorize_athlete, axis=1)

# %%
bios.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg  \
# 0               Gironde          FRA  France        NaN        NaN
# 1              Yvelines          FRA  France      183.0       76.0
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0
# 3                 Paris          FRA  France      168.0       64.0
# 4               England          GBR  France        NaN        NaN
#
#     died_date height_category      Category
# 0  1960-10-02            Tall   Heavyweight
# 1         NaN         Average  Middleweight
# 2  1994-07-17         Average  Middleweight
# ...

# %% [markdown]
# MERGING AND CONCATING DATA

# %%
nocs = pd.read_csv('./data/noc_regions.csv')

# %%
pd.merge(bios,nocs,left_on='born_country',right_on='NOC',how='inner',suffixes=['-left','-right'])
# Out:
#         athlete_id                   name   born_date        born_city  \
# 0                1  Jean-François Blanchy  1886-12-12         Bordeaux
# 1                2         Arnaud Boetsch  1969-04-01           Meulan
# 2                3           Jean Borotra  1898-08-13         Biarritz
# 3                4        Jacques Brugnon  1895-05-11      Paris VIIIe
# 4                5           Albert Canet  1878-04-17       Wandsworth
# ...            ...                    ...         ...              ...
# 110634      149222      Polina Luchnikova  2002-01-30            Serov
# 110635      149223    Valeriya Merkusheva  1999-09-20  Moskva (Moscow)
# 110636      149224        Yuliya Smirnova  1998-05-08           Kotlas
# 110637      149225         André Foussard  1899-05-19            Niort
# 110638      149814          Bill Phillips  1913-07-15     Dulwich Hill
#
#                  born_region born_country   NOC-left  height_cm  weight_kg  \
# ...

# %%
usa = bios[bios['born_country'] == 'USA'].copy()
gbr = bios[bios['born_country'] == 'GBR'].copy()

# %%
usa.head()
# Out:
#       athlete_id               name   born_date         born_city born_region  \
# 54            55      Monique Javer  1967-07-22        Burlingame  California
# 960          964   Xóchitl Escobedo  1968-09-17       West Covina  California
# 961          965  Angélica Gavaldón  1973-10-03         El Centro  California
# 1231        1238     Bert Schneider  1897-07-01         Cleveland        Ohio
# 1345        1352         Laura Berg  1975-01-06  Santa Fe Springs  California
#
#      born_country            NOC  height_cm  weight_kg   died_date  \
# 54            USA  Great Britain      177.0       64.0         NaN
# 960           USA         Mexico      170.0       60.0         NaN
# 961           USA         Mexico      160.0       54.0         NaN
# 1231          USA         Canada        NaN        NaN  1986-02-20
# 1345          USA  United States      168.0       61.0         NaN
#
#      height_category      Category
# 54           Average  Middleweight
# ...

# %%
new_df = pd.concat([usa,gbr])

# %%
new_df
# Out:
#         athlete_id                name   born_date         born_city  \
# 54              55       Monique Javer  1967-07-22        Burlingame
# 960            964    Xóchitl Escobedo  1968-09-17       West Covina
# 961            965   Angélica Gavaldón  1973-10-03         El Centro
# 1231          1238      Bert Schneider  1897-07-01         Cleveland
# 1345          1352          Laura Berg  1975-01-06  Santa Fe Springs
# ...            ...                 ...         ...               ...
# 144811      148512  Benjamin Alexander  1983-05-08            London
# 144815      148517       Ashley Watson  1993-10-28      Peterborough
# 145005      148716     Peder Kongshaug  2001-08-13         Wimbledon
# 145319      149041          Axel Brown  1992-04-02         Harrogate
# 145388      149111      Jean-Luc Baker  1993-10-07           Burnley
#
#        born_region born_country                  NOC  height_cm  weight_kg  \
# ...

# %%
results = pd.read_parquet('./data/results.parquet')

# %%
combined_df = pd.merge(results,bios,on='athlete_id',how='left')
combined_df
# Out:
#           year    type              discipline                          event  \
# 0       1912.0  Summer                  Tennis         Singles, Men (Olympic)
# 1       1912.0  Summer                  Tennis         Doubles, Men (Olympic)
# 2       1920.0  Summer                  Tennis         Singles, Men (Olympic)
# 3       1920.0  Summer                  Tennis       Doubles, Mixed (Olympic)
# 4       1920.0  Summer                  Tennis         Doubles, Men (Olympic)
# ...        ...     ...                     ...                            ...
# 308403  2022.0  Winter                    Luge         Singles, Men (Olympic)
# 308404  2022.0  Winter  Alpine Skiing (Skiing)        Slalom, Women (Olympic)
# 308405  2022.0  Winter  Alpine Skiing (Skiing)          Team, Mixed (Olympic)
# 308406  2022.0  Winter  Alpine Skiing (Skiing)  Giant Slalom, Women (Olympic)
# 308407  2022.0  Winter                    None        Slalom, Women (Olympic)
#
# ...

# %% [markdown]
# HANDLING NULL

# %%
coffee.loc[[0,1],'Units Sold'] = np.nan

# %%
# # coffee  = coffee.fillna(10000)
# coffee['Units Sold']  = 
coffee['Units Solds'] = coffee['Units Sold'].interpolate()

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold  Units Solds
# 0      Monday    Espresso         NaN          NaN
# 1      Monday       Latte         NaN          NaN
# 2     Tuesday    Espresso        30.0         30.0
# 3     Tuesday       Latte        20.0         20.0
# 4   Wednesday    Espresso        35.0         35.0
# 5   Wednesday       Latte        25.0         25.0
# 6    Thursday    Espresso        40.0         40.0
# 7    Thursday       Latte        30.0         30.0
# 8      Friday    Espresso        45.0         45.0
# 9      Friday       Latte        35.0         35.0
# 10   Saturday    Espresso        45.0         45.0
# 11   Saturday       Latte        35.0         35.0
# 12     Sunday    Espresso        45.0         45.0
# 13     Sunday       Latte        35.0         35.0
